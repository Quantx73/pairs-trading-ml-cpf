# %%
# Test du module baseline
import sys
print("Chemin courant:", sys.path[0])

# Vérifier que les dossiers existent
import os
print("Contenu de ./data:", os.listdir('./data'))
print("Contenu de ./src:", os.listdir('./src'))

# Importer et tester
from src.baseline import run_baseline_strategy
import pandas as pd

# Charger les données
data = pd.read_csv('./data/pairs_data.csv', index_col=0, parse_dates=True)
print("✅ Données chargées:", data.shape)
print(data.head())
# Out:
# Chemin courant: C:\Users\nabyl\miniconda3\python312.zip
# Contenu de ./data: ['ewa_ewc_prices.csv', 'pairs_data.csv']
# Contenu de ./src: ['.ipynb_checkpoints', 'backtest.py', 'baseline.py', 'features.py', 'models.py', 'notebooks', '__pycache__']
# ✅ Données chargées: (2608, 2)
#               Asset_A     Asset_B
# 2014-01-01  99.771931   99.731125
# 2014-01-02  98.701208  100.015409
# 2014-01-03  99.474953  100.568176
# 2014-01-06  97.483925   99.420452
# 2014-01-07  98.256977  100.591684
